// %% [markdown]
// # References
// * [Bubble Sort – Data Structure and Algorithm Tutorials - geeksforgeeks.org](https://www.geeksforgeeks.org/bubble-sort/)

// %%
function printPointers(baseArr,baseIndex,PlusOne){
    console.log('[index] = value');
    
        for( let index = 0; index < baseArr.length; index++){
        
        let label = "";
        
        if(baseIndex == index || PlusOne == index){
            label = label + "<---- ";
            
            if(baseIndex == index){
                label = label +" BaseIndex";
            }
            
            if(PlusOne == index){
                label = label +" PlusOne";
            }
            
        }
        
        
        
        console.log(`[ ${index} ] = ${baseArr[index]}  ${label} \n`)
    }
}

// %%
// Optimized javaScript implementation
// of Bubble sort
// An optimized version of Bubble Sort
function bubbleSort(arr, n)
{
    var i, j, temp;
    var swapped;
    for (i = 0; i < n - 1; i++) 
    {
        console.log('_____________________'); 
        swapped = false;
        for (j = 0; j < n - i -1; j++) 
        {
            if (arr[j] > arr[j + 1]) 
            {
                // Swap arr[j] and arr[j+1]
                temp = arr[j];
                arr[j] = arr[j + 1];
                arr[j + 1] = temp;
                swapped = true;
            }
            printPointers(arr,i,j);  
                      
        }
 
        // IF no two elements were 
        // swapped by inner loop, then break
        if (swapped == false)
        break;
    }
}

// %%
// Function to print an array 
function printArray(arr, size)
{
  var i;
  for (i = 0; i < size; i++)
      console.log(arr[i] + " ");
}

// %%
// Driver program
var arr = [ 64, 34, 25, 12, 22, 11, 90 ];
var n = arr.length;
bubbleSort(arr, n);
//console.log("Sorted array: ");
//printArray(arr, n);
// Out:
// _____________________
// [index] = value
// [ 0 ] = 34  <----  BaseIndex PlusOne
//
// [ 1 ] = 64
//
// [ 2 ] = 25
//
// [ 3 ] = 12
//
// [ 4 ] = 22
//
// [ 5 ] = 11
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 34  <----  BaseIndex
//
// [ 1 ] = 25  <----  PlusOne
//
// [ 2 ] = 64
//
// [ 3 ] = 12
//
// [ 4 ] = 22
//
// [ 5 ] = 11
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 34  <----  BaseIndex
//
// [ 1 ] = 25
//
// [ 2 ] = 12  <----  PlusOne
//
// [ 3 ] = 64
//
// [ 4 ] = 22
//
// [ 5 ] = 11
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 34  <----  BaseIndex
//
// [ 1 ] = 25
//
// [ 2 ] = 12
//
// [ 3 ] = 22  <----  PlusOne
//
// [ 4 ] = 64
//
// [ 5 ] = 11
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 34  <----  BaseIndex
//
// [ 1 ] = 25
//
// [ 2 ] = 12
//
// [ 3 ] = 22
//
// [ 4 ] = 11  <----  PlusOne
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 34  <----  BaseIndex
//
// [ 1 ] = 25
//
// [ 2 ] = 12
//
// [ 3 ] = 22
//
// [ 4 ] = 11
//
// [ 5 ] = 64  <----  PlusOne
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 34  <----  BaseIndex
//
// [ 1 ] = 25
//
// [ 2 ] = 12
//
// [ 3 ] = 22
//
// [ 4 ] = 11
//
// [ 5 ] = 64
//
// [ 6 ] = 90  <----  PlusOne
//
// _____________________
// [index] = value
// [ 0 ] = 25  <----  PlusOne
//
// [ 1 ] = 34  <----  BaseIndex
//
// [ 2 ] = 12
//
// [ 3 ] = 22
//
// [ 4 ] = 11
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 25
//
// [ 1 ] = 12  <----  BaseIndex PlusOne
//
// [ 2 ] = 34
//
// [ 3 ] = 22
//
// [ 4 ] = 11
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 25
//
// [ 1 ] = 12  <----  BaseIndex
//
// [ 2 ] = 22  <----  PlusOne
//
// [ 3 ] = 34
//
// [ 4 ] = 11
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 25
//
// [ 1 ] = 12  <----  BaseIndex
//
// [ 2 ] = 22
//
// [ 3 ] = 11  <----  PlusOne
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 25
//
// [ 1 ] = 12  <----  BaseIndex
//
// [ 2 ] = 22
//
// [ 3 ] = 11
//
// [ 4 ] = 34  <----  PlusOne
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 25
//
// [ 1 ] = 12  <----  BaseIndex
//
// [ 2 ] = 22
//
// [ 3 ] = 11
//
// [ 4 ] = 34
//
// [ 5 ] = 64  <----  PlusOne
//
// [ 6 ] = 90
//
// _____________________
// [index] = value
// [ 0 ] = 12  <----  PlusOne
//
// [ 1 ] = 25
//
// [ 2 ] = 22  <----  BaseIndex
//
// [ 3 ] = 11
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 12
//
// [ 1 ] = 22  <----  PlusOne
//
// [ 2 ] = 25  <----  BaseIndex
//
// [ 3 ] = 11
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 12
//
// [ 1 ] = 22
//
// [ 2 ] = 11  <----  BaseIndex PlusOne
//
// [ 3 ] = 25
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 12
//
// [ 1 ] = 22
//
// [ 2 ] = 11  <----  BaseIndex
//
// [ 3 ] = 25  <----  PlusOne
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 12
//
// [ 1 ] = 22
//
// [ 2 ] = 11  <----  BaseIndex
//
// [ 3 ] = 25
//
// [ 4 ] = 34  <----  PlusOne
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// _____________________
// [index] = value
// [ 0 ] = 12  <----  PlusOne
//
// [ 1 ] = 22
//
// [ 2 ] = 11
//
// [ 3 ] = 25  <----  BaseIndex
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 12
//
// [ 1 ] = 11  <----  PlusOne
//
// [ 2 ] = 22
//
// [ 3 ] = 25  <----  BaseIndex
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 12
//
// [ 1 ] = 11
//
// [ 2 ] = 22  <----  PlusOne
//
// [ 3 ] = 25  <----  BaseIndex
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 12
//
// [ 1 ] = 11
//
// [ 2 ] = 22
//
// [ 3 ] = 25  <----  BaseIndex PlusOne
//
// [ 4 ] = 34
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// _____________________
// [index] = value
// [ 0 ] = 11  <----  PlusOne
//
// [ 1 ] = 12
//
// [ 2 ] = 22
//
// [ 3 ] = 25
//
// [ 4 ] = 34  <----  BaseIndex
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 11
//
// [ 1 ] = 12  <----  PlusOne
//
// [ 2 ] = 22
//
// [ 3 ] = 25
//
// [ 4 ] = 34  <----  BaseIndex
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 11
//
// [ 1 ] = 12
//
// [ 2 ] = 22  <----  PlusOne
//
// [ 3 ] = 25
//
// [ 4 ] = 34  <----  BaseIndex
//
// [ 5 ] = 64
//
// [ 6 ] = 90
//
// _____________________
// [index] = value
// [ 0 ] = 11  <----  PlusOne
//
// [ 1 ] = 12
//
// [ 2 ] = 22
//
// [ 3 ] = 25
//
// [ 4 ] = 34
//
// [ 5 ] = 64  <----  BaseIndex
//
// [ 6 ] = 90
//
// [index] = value
// [ 0 ] = 11
//
// [ 1 ] = 12  <----  PlusOne
//
// [ 2 ] = 22
//
// [ 3 ] = 25
//
// [ 4 ] = 34
//
// [ 5 ] = 64  <----  BaseIndex
//
// [ 6 ] = 90
